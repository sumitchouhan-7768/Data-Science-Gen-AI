# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as st
# %matplotlib inline
sns.set(style="whitegrid")

# %%
#ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\HP\Downloads\NARESH IT\30th- Seaborn, Eda practicle\EDA\heart.csv")

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
df.shape
# Out:
# (303, 14)

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
df.describe(include='all')
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
df['target'].nunique()
# Out:
# 2

# %%
df['target'].unique()
# Out:
# array([1, 0], dtype=int64)

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
# the presence of heart disease = 1, and Absence of heart disease = 0

# %%
df['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
# therefore there are total of 165 people with heart disease and 138 with Absence of heat disease

# %%
f,ax = plt.subplots(figsize = (8,6))
ax = sns.countplot(x="target",data=df)
plt.show()

# %%
df.groupby('sex')['target'].value_counts()
# Out:
# sex  target
# 0    1          72
#      0          24
# 1    0         114
#      1          93
# Name: target, dtype: int64

# %% [markdown]
# # Conclusion
# '''sex :- 1 = male , 0 = female.
# target: 1 = presence of heart disease, 0 = Absence of heart disease.
# therfore:- out of 96 females - 72 have heart disease and 24 do not have heart disease.
# similarly, out of 207 males - 114 have heart disease and 93 do not have heart disease.'''

# %%
f,ax = plt.subplots(figsize=(8,6))
ax = sns.countplot(x="sex",hue='target',data=df)
plt.show()

# %%
ax= sns.catplot(x="target",col="sex",data=df,kind="count",height=5,aspect=1)

# %%
f,ax = plt.subplots(figsize=(8,6))
ax = sns.countplot(x="target",data=df,palette="Set3")
plt.show()

# %%
f, ax= plt.subplots(figsize = (8,6))
ax = sns.countplot(x="target",data=df,facecolor=(0,0,0,0),linewidth=5,edgecolor=sns.color_palette("dark",3))
plt.show()

# %%
# ploting visualization with fbs(fasting blood sugar) and exang(exercise induced agina)

# %%
f,ax= plt.subplots(figsize=(8,6))
ax=sns.countplot(x="target",hue="fbs",data=df)
plt.show()

# %%
f,ax= plt.subplots(figsize=(8,6))
ax=sns.countplot(x="target",hue="exang",data=df)
plt.show()

# %% [markdown]
# # BIVARIATE ANALYSIS

# %%
correlation = df.corr()

# %%
correlation['target'].sort_values(ascending=False)
# Out:
# target      1.000000
# cp          0.433798
# thalach     0.421741
# slope       0.345877
# restecg     0.137230
# fbs        -0.028046
# chol       -0.085239
# trestbps   -0.144931
# age        -0.225439
# sex        -0.280937
# thal       -0.344029
# ca         -0.391724
# oldpeak    -0.430696
# exang      -0.436757
# Name: target, dtype: float64

# %% [markdown]
# *The correlation coefficient ranges from -1 to +1.
#
# *when it is close to +1, this signifies that there is a stron positive correlation .so, we can se that there is no variable which has strong positive correlation with "target" variable.
#
# *when it is close to -1,this signifies that there is a strong negative correlation . so, we can see that there is no veriable which has strong negative correlation with "target" variable.
#
# *when it is close to 0,it means that there is no correlation .so, there is no correlation bethween "target" and "fbs".
#
# *we can see that thw "cp" and "thalach" variable are mildly positively correlated with "target" variable . so, i will analyze the interaction between these features and "terget" variable.

# %%
df['cp'].nunique()
# Out:
# 4

# %%
df['cp'].unique()
# Out:
# array([3, 2, 1, 0], dtype=int64)

# %%
# frequency distribution 
df['cp'].value_counts()
# Out:
# 0    143
# 2     87
# 1     50
# 3     23
# Name: cp, dtype: int64

# %% [markdown]
# * it can be seen that  "cp" is a categorical variable and it contains 4 types of values = 0,1,2 and 3.

# %%
#visualization of frequency distribution

# %%
f, ax= plt.subplots(figsize=(8,6))
ax=sns.countplot(x="cp",data=df)
plt.show()

# %%
# frequency distribution of "target"  with "cp"

# %%
df.groupby("cp")["target"].value_counts()
# Out:
# cp  target
# 0   0         104
#     1          39
# 1   1          41
#     0           9
# 2   1          69
#     0          18
# 3   1          16
#     0           7
# Name: target, dtype: int64

# %% [markdown]
# #### Comment
#
#
# - `cp` variable contains four integer values 0, 1, 2 and 3.
#
# - `target` variable contains two integer values 1 and 0 : (1 = Presence of heart disease; 0 = Absence of heart disease)
#
# - So, the above analysis gives `target` variable values categorized into presence and absence of heart disease and groupby `cp` variable values.
#
# - We can visualize this information below.

# %%
#viaulization of value count of "cp" with "target"

# %%
f,ax= plt.subplots(figsize=(8,6))
ax= sns.countplot(x="cp",hue="target",data=df)
plt.show()

# %% [markdown]
# #### Interpretation
#
# - We can see that the values of `target` variable are plotted wrt `cp`.
#
# - `target` variable contains two integer values 1 and 0 : (1 = Presence of heart disease; 0 = Absence of heart disease)
#
# - The above plot confirms our above findings,

# %%
ax = sns.catplot(x= "target",col="cp",data=df,kind="count",height=8,aspect=1)

# %%
df['thalach'].nunique()
# Out:
# 91

# %%
#frequecy distribution of thalach.

# %%
f,ax = plt.subplots(figsize=(10,6))
x = df['thalach']
ax= sns.distplot(x,bins=10)
plt.show()

# %%
# thr "thalach" varible is slightly negativre skewed

# %%
f, ax= plt.subplots(figsize=(10,6))
x= df['thalach']
x= pd.Series(x,name="thalach variable")
ax=sns.distplot(x,bins=10)
plt.show()

# %%
ax= plt.subplots(figsize=(10,6))
x=df['thalach']
x=pd.Series(x,name="thalach variable")
ax=sns.kdeplot(x)
plt.show()

# %%
ax= plt.subplots(figsize=(10,6))
x=df['thalach']
x=pd.Series(x,name="thalach variable")
ax=sns.kdeplot(x,shade=True,color='r')
plt.show()

# %%
ax = plt.subplots(figsize=(10,6))
x= df['thalach']
ax=sns.distplot(x,kde=True,rug=True,bins=10)
plt.show()

# %%
ax=plt.subplots(figsize=(10,6))
sns.stripplot(x='target',y='thalach',data=df)
plt.show()

# %% [markdown]
# #### Interpretation
#
# - We can see that those people suffering from heart disease (target = 1) have relatively higher heart rate (thalach) as compared to people who are not suffering from heart disease (target = 0).

# %%
ax=plt.subplots(figsize=(10,6))
sns.stripplot(x='target',y='thalach',data=df,jitter=0.01)
plt.show()

# %%
ax=plt.subplots(figsize=(10,6))
sns.boxplot(x='target',y='thalach',data=df)
plt.show()

# %% [markdown]
# #### Interpretation
#
# The above boxplot confirms our finding that people suffering from heart disease (target = 1) have relatively higher heart rate (thalach) as compared to people who are not suffering from heart disease (target = 0).

# %% [markdown]
# ### Findings of Bivariate Analysis <a class="anchor" id="8.4"></a>
#
# Findings of Bivariate Analysis are as follows –
#
#
# - There is no variable which has strong positive correlation with `target` variable.
#
# - There is no variable which has strong negative correlation with `target` variable.
#
# - There is no correlation between `target` and `fbs`.
#
# - The `cp` and `thalach` variables are mildly positively correlated with `target` variable.
#
# - We can see that the `thalach` variable is slightly negatively skewed.
#
# - The people suffering from heart disease (target = 1) have relatively higher heart rate (thalach) as compared to people who are not suffering from heart disease (target = 0).
#
# - The people suffering from heart disease (target = 1) have relatively higher heart rate (thalach) as compared to people who are not suffering from heart disease (target = 0).

# %%
#let create a heatmap to find out the patterns and relationships in the dataset

# %%
plt.figure(figsize=(16,12))
plt.title('Correlation Heatmap of Heart Disease Dataset')
a = sns.heatmap(correlation,square=True,annot=True,fmt='.2f',linecolor='white')
a.set_xticklabels(a.get_xticklabels(),rotation=90)
a.set_yticklabels(a.get_yticklabels(),rotation=30)
plt.show()

# %% [markdown]
# #### Interpretation
#
# From the above correlation heat map, we can conclude that :-
#
# - `target` and `cp` variable are mildly positively correlated (correlation coefficient = 0.43).
#
# - `target` and `thalach` variable are also mildly positively correlated (correlation coefficient = 0.42).
#
# - `target` and `slope` variable are weakly positively correlated (correlation coefficient = 0.35).
#
# - `target` and `exang` variable are mildly negatively correlated (correlation coefficient = -0.44).
#
# - `target` and `oldpeak` variable are also mildly negatively correlated (correlation coefficient = -0.43).
#
# - `target` and `ca` variable are weakly negatively correlated (correlation coefficient = -0.39).
#
# - `target` and `thal` variable are also waekly negatively correlated (correlation coefficient = -0.34).

# %%
num_var = ['age','trestbps','chol','thalach','oldpeak','target',]
sns.pairplot(df[num_var],kind='scatter',diag_kind='hist')
plt.show()

# %%
df['age'].nunique()
# Out:
# 41

# %%
df['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
df['age'].unique()
# Out:
# array([63, 37, 41, 56, 57, 44, 52, 54, 48, 49, 64, 58, 50, 66, 43, 69, 59,
#        42, 61, 40, 71, 51, 65, 53, 46, 45, 39, 47, 62, 34, 35, 29, 55, 60,
#        67, 68, 74, 76, 70, 38, 77], dtype=int64)

# %%
# the mean value in age = 54.37
#the minimum and maximum value in age are as follows = 29 and 77 years.

# %%
ax=plt.subplots(figsize=(10,6))
x=df['age']
ax=sns.distplot(x,bins=10)
plt.show()

# %%
#the age variable distribution is aprox. normal.

# %%
ax = plt.subplots(figsize=(10,6))
sns.stripplot(x='target',y='age',data=df)
plt.show()

# %%
ax = plt.subplots(figsize=(10,6))
sns.stripplot(x='target',y='age',data=df,jitter=0.01)
plt.show()

# %%
ax= plt.subplots(figsize=(10,6))
sns.boxplot(x='target',y='age',data=df)
plt.show()

# %% [markdown]
# #### Interpretation
#
# - The above boxplot tells two different things :
#
#   - The mean age of the people who have heart disease is less than the mean age of the people who do not have heart disease.
#
#   - The dispersion or spread of age of the people who have heart disease is greater than the dispersion or spread of age of the people who do not have heart disease.

# %%
# lets plot a scatter plot to visualize the relationship btw age and trestbps variable

# %%
ax= plt.subplots(figsize=(10,6))
ax=sns.scatterplot(x='age',y='trestbps',data=df)
plt.show()

# %% [markdown]
# #### Interpretation
#
# - The above scatter plot shows that there is no correlation between `age` and `trestbps` variable.

# %% [markdown]
# Positive Correlation:
#
# If the points on the scatter plot trend upward from left to right, it indicates a positive correlation.
# In this case, as one variable increases, the other variable also tends to increase.
# A strong positive correlation will have points clustered close to a straight line, while a weak positive correlation will have a more dispersed pattern.
#
# Negative Correlation:
#
# If the points trend downward from left to right, it indicates a negative correlation.
# Here, as one variable increases, the other tends to decrease.
# Like with positive correlation, the strength is shown by how closely the points cluster around a line.
#
# No Correlation:
#
# If the points are scattered with no apparent trend, it suggests no correlation.
# In this case, changes in one variable do not correspond consistently with changes in the other.
#
# Non-Linear Relationships:
#
# Sometimes, the scatter plot might show a curved or non-linear trend, indicating a more complex relationship between the variables.
# For example, a U-shaped scatter suggests that the relationship is quadratic rather than linear.
#
# Outliers:
#
# Outliers are points that don’t fit the general pattern of the data. They can distort the appearance of correlation and might indicate unusual cases or errors.

# %%
ax= plt.subplots(figsize=(10,6))
ax=sns.regplot(x='age',y='trestbps',data=df)
plt.show()

# %%
#the above visual shows that the linear regression model is not the good fit to the data.

# %%
ax=plt.subplots(figsize=(10,6))
ax=sns.scatterplot(x='age',y='chol',data=df)
plt.show()

# %%
ax=plt.subplots(figsize=(10,6))
ax=sns.regplot(x='age',y='chol',data=df)
plt.show()

# %% [markdown]
# #### Interpretation
#
# - The above plot confirms that there is a slighly positive correlation between `age` and `chol` variables.

# %% [markdown]
# A regression plot (or regplot) is an enhanced scatter plot that includes a regression line, making it even easier to understand the correlation between two variables. Here’s how to interpret it:
#
# Positive Correlation:
#
# If the regression line slopes upward from left to right, it suggests a positive correlation.
# This means as one variable increases, the other also tends to increase.
# The closer the data points are to this line, the stronger the positive correlation.
#
# Negative Correlation:
#
# If the regression line slopes downward from left to right, it indicates a negative correlation.
# In this case, as one variable increases, the other tends to decrease.
# A tighter clustering around the line indicates a stronger negative correlation.
#
# No Correlation:
#
# If the regression line is nearly horizontal or very shallow, it suggests little to no linear correlation.
# Points would likely appear scattered around the line without any consistent upward or downward trend.
#
# Confidence Interval:
#
# Many regression plots also show a shaded region around the regression line, representing the confidence interval.
# A narrow confidence interval suggests a more reliable relationship between the variables, while a wider interval indicates more uncertainty.
#
# Outliers:
#
# Outliers can be easily spotted as points far from the regression line. They can affect the slope and interpretation of the line, sometimes giving a misleading impression of the correlation.

# %%
ax=plt.subplots(figsize=(10,6))
ax = sns.scatterplot(x='chol',y='thalach',data=df)
plt.show()

# %%
ax=plt.subplots(figsize=(10,6))
ax = sns.regplot(x='chol',y='thalach',data=df)
plt.show()

# %% [markdown]
# #### Interpretation
#
#
# - The above plot shows that there is no correlation between `chol` and `thalach` variable.

# %%
# checking for missing values

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# there is no missing values in the dataset.

# %%
assert pd.notnull(df).all().all()

# %%
assert (df>=0).all().all()

# %% [markdown]
# #### Interpretation
#
# - The above two commands do not throw any error. Hence, it is confirmed that there are no missing or negative values in the dataset.
#
# - All the values are greater than or equal to zero.

# %%
# lets detect the outliers

# %%
df['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
ax=plt.subplots(figsize=(10,6))
sns.boxplot(x=df['age'])
plt.show()

# %%
df['trestbps'].describe()
# Out:
# count    303.000000
# mean     131.623762
# std       17.538143
# min       94.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: trestbps, dtype: float64

# %%
ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=df["trestbps"])
plt.show()

# %%
df['chol'].describe()
# Out:
# count    303.000000
# mean     246.264026
# std       51.830751
# min      126.000000
# 25%      211.000000
# 50%      240.000000
# 75%      274.500000
# max      564.000000
# Name: chol, dtype: float64

# %%
ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=df["chol"])
plt.show()

# %%
df['thalach'].describe()
# Out:
# count    303.000000
# mean     149.646865
# std       22.905161
# min       71.000000
# 25%      133.500000
# 50%      153.000000
# 75%      166.000000
# max      202.000000
# Name: thalach, dtype: float64

# %%
ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=df["thalach"])
plt.show()

# %%
df['oldpeak'].describe()
# Out:
# count    303.000000
# mean       1.039604
# std        1.161075
# min        0.000000
# 25%        0.000000
# 50%        0.800000
# 75%        1.600000
# max        6.200000
# Name: oldpeak, dtype: float64

# %%
ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=df["oldpeak"])
plt.show()

# %% [markdown]
# #### Findings
#
# - The `age` variable does not contain any outlier.
#
# - `trestbps` variable contains outliers to the right side.
#
# - `chol` variable also contains outliers to the right side.
#
# - `thalach` variable contains a single outlier to the left side.
#
# - `oldpeak` variable contains outliers to the right side.
#
# - Those variables containing outliers needs further investigation.
